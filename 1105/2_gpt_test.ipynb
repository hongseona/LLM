# %%
from dotenv import load_dotenv

# .env 파일에서 OPENAI_API_KEY 이름의 key 값을 가져옵니다.
# -> OpenAI() 객체 생성할 때 사용합니다.
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

# 모델 : gpt-4.1-mini
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        # 상담사 역할 정의
        {
            "role": "system",
            "content": (
                "당신은 전문 심리상담사입니다. "
                "따뜻하고 공감적인 태도로 대화하며, "
                "사용자의 감정을 존중하고 안전한 분위기를 조성하세요. "
                "직접적인 진단이나 치료 지시는 하지 말고, "
                "대화를 통해 사용자가 스스로 생각을 정리할 수 있도록 돕습니다."
            ) + "그리고 , 다른 질문 또는 심리상담과 상관없는 내용은 '모릅니다.' 로 반드시 답변하기."
        },
        # 내담자(사용자) 메시지
        {
            "role": "user",
            "content": (
                "요즘 일이 너무 많아서 스트레스를 많이 받고 있어요. "
                "밤에도 잠을 잘 못 자고, 계속 불안한 기분이 듭니다."
            )
        }
    ],
    temperature=0.7,  
    # 출력의 창의성과 무작위성을 조절하는 파라미터.(0~1  :사용하는 단어 일반적~창의적)
    max_tokens=300
)
print(response.model_dump_json(indent=2))
# print(response.choices[0].message["content"])
# Out:
# {
#   "id": "chatcmpl-CYjBiSyWENl0uTD8cvlL4EdalOiY5",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "힘든 상황이 계속되면서 잠도 잘 못 자고 불안감까지 느끼시니 많이 지치셨겠어요. 일이 많아 스트레스가 쌓이면 몸과 마음 모두가 영향을 받기 쉽죠. 혹시 요즘 어떤 생각들이 가장 많이 떠오르시나요? 그리고 불안할 때 본인만의 대처 방법이 있나요? 함께 이야기 나누면서 조금이라도 마음이 편해지셨으면 좋겠어요.",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762392890,
#   "model": "gpt-4.1-mini-2025-04-14",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_4c2851f862",
#   "usage": {
#     "completion_tokens": 98,
#     "prompt_tokens": 139,
#     "total_tokens": 237,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
# ...

# %%
print(f'💬 AI : {response.choices[0].message.content}')
# Out:
# 💬 AI : 힘든 상황이 계속되면서 잠도 잘 못 자고 불안감까지 느끼시니 많이 지치셨겠어요. 일이 많아 스트레스가 쌓이면 몸과 마음 모두가 영향을 받기 쉽죠. 혹시 요즘 어떤 생각들이 가장 많이 떠오르시나요? 그리고 불안할 때 본인만의 대처 방법이 있나요? 함께 이야기 나누면서 조금이라도 마음이 편해지셨으면 좋겠어요.

# %%
# 참고 : 응답 객체의 key , 구조가 gpt-4과 비교하면 변경되었습니다.
# 모델 : gpt-5-nano
response = client.responses.create(
    model="gpt-5-nano",
    input="Write a one-sentence bedtime story about a unicorn."
)
print(response.model_dump_json(indent=2))
print(f'💬AI :{response.output_text}')
# Out:
# {
#   "id": "resp_05ca810f78b8a98400690bfb3cc7348197a453a4b40a86024a",
#   "created_at": 1762392892.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": null,
#   "metadata": {},
#   "model": "gpt-5-nano-2025-08-07",
#   "object": "response",
#   "output": [
#     {
#       "id": "rs_05ca810f78b8a98400690bfb3d36248197bb1453889241809e",
#       "summary": [],
#       "type": "reasoning",
#       "content": null,
#       "encrypted_content": null,
#       "status": null
#     },
#     {
#       "id": "msg_05ca810f78b8a98400690bfb3fe5a4819785f3918d67327be2",
#       "content": [
#         {
#           "annotations": [],
#           "text": "Under the silver moon, a gentle unicorn trotted through a sleeping meadow, brushing starlight from its mane as it curled up and drifted into dreamland.",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message"
# ...
