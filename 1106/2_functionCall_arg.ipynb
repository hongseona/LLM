# %%
# !python ai_responseV2.py

# %%
from ai_responseV2 import get_ai_response,get_first_response_tz,get_followup_response_tz

# %%
question = '뉴욕은 몇시야?' #'서울은 어느 나라야?'
response = get_first_response_tz(question)
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-CYnpriNu51iRjUC0XNo3ZFbdOTOWZ",
#   "choices": [
#     {
#       "finish_reason": "function_call",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": null,
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": {
#           "arguments": "{\"timezone\":\"America/New_York\"}",
#           "name": "get_current_time_tz"
#         },
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762410755,
#   "model": "gpt-4o-2024-08-06",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_cbf1785567",
#   "usage": {
#     "completion_tokens": 20,
#     "prompt_tokens": 163,
#     "total_tokens": 183,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
import json
from ai_responseV2 import get_current_time_tz, get_current_date_tz
fn_name = getattr(response.choices[0].message.function_call, "name", None)
tz = json.loads(response.choices[0].message.function_call.arguments)
print(f'log tz : {tz}')
func_response =  globals()[fn_name](**tz)
print(f'log func_response : {func_response}')
followup_response=get_followup_response_tz(fn_name,func_response)
# Out:
# log tz : {'timezone': 'America/New_York'}
# 🔄log : 현재 시간(tz) : 01:43:11 America/New_York
# log func_response : 01:43:11

# %%
question = '뉴욕의 날짜와 시간을 알려줘?' #'서울은 어느 나라야?'
final_response = get_ai_response(question)
print(f'💬AI : {final_response}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 question = '뉴욕의 날짜와 시간을 알려줘?' #'서울은 어느 나라야?'
# ----> 2 final_response = get_ai_response(question)
#       3 print(f'💬AI : {final_response}')
#
# File c:\Class250615\llm_Workspace\1106\ai_responseV2.py:14, in get_ai_response(question, functions)
#      10 fn_name = getattr(response.choices[0].message.function_call, "name", None)
#      11 if fn_name:
#      12  # 함수 호출 : get_current_time_tz ,get_current_date_tz 는 인자가 필요합니다.
#      13  # funcion_call.arguments 를 dict 로 변환
# ---> 14  tz = json.loads(response.choices[0].message.funcion_call.arguments)
#      15  func_response =  globals()[fn_name](**tz)
#      16  followup_response=get_followup_response_tz(fn_name,func_response)
#
# File c:\Users\C106\miniconda3\envs\llmEnv\Lib\site-packages\pydantic\main.py:991, in BaseModel.__getattr__(self, item)
#     988     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     989 else:
#     990     # this is the current error
# --> 991     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ChatCompletionMessage' object has no attribute 'funcion_call'

# %%
question = '뉴욕은 지금 몇일 이야?'  #'서울은 어느 나라야?'
final_response = get_ai_response(question)
print(f'💬AI : {final_response}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 question = '뉴욕은 지금 몇일 이야?'  #'서울은 어느 나라야?'
# ----> 2 final_response = get_ai_response(question)
#       3 print(f'💬AI : {final_response}')
#
# File c:\Class250615\llm_Workspace\1106\ai_responseV2.py:14, in get_ai_response(question, functions)
#      10 fn_name = getattr(response.choices[0].message.function_call, "name", None)
#      11 if fn_name:
#      12  # 함수 호출 : get_current_time_tz ,get_current_date_tz 는 인자가 필요합니다.
#      13  # funcion_call.arguments 를 dict 로 변환
# ---> 14  tz = json.loads(response.choices[0].message.funcion_call.arguments)
#      15  func_response =  globals()[fn_name](**tz)
#      16  followup_response=get_followup_response_tz(fn_name,func_response)
#
# File c:\Users\C106\miniconda3\envs\llmEnv\Lib\site-packages\pydantic\main.py:991, in BaseModel.__getattr__(self, item)
#     988     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     989 else:
#     990     # this is the current error
# --> 991     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ChatCompletionMessage' object has no attribute 'funcion_call'
