# %%
from mylib import trip_tools_Agent as tta

# %%
# user_input='2025년 12월 서울에서 열리는 축제 알려줘'
# user_input='좋아. 구체적인 일정 알려줘'
user_input='방금 무슨 이야기 하던 중이지?'
ai_result = tta.run_agent_memory(user_input=user_input, thread_id="1003")
print(ai_result)
# Out:
# ...
# 👤 사용자: 방금 무슨 이야기 하던 중이지?
# ...
# 2025-11-12 11:43:07,051 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 🤖 어시스턴트:
# ...
